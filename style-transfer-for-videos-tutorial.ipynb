# %% [markdown]
# <a href="https://colab.research.google.com/github/zhou671/STRAVE/blob/master/style-transfer-for-videos-tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone Our GitHub Repo

# %%
# %cd /content/
# !git clone https://github.com/zhou671/STRAVE.git
# Out:
# /content
# Cloning into 'STRAVE'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 174 (delta 89), reused 131 (delta 46), pack-reused 0
# Receiving objects: 100% (174/174), 2.54 MiB | 11.24 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %% [markdown]
# # Install DeepMatching GPU Version
# [DeepMatching](https://thoth.inrialpes.fr/src/deepmatching/) is a matching algorithm developped by Jerome Revaud in 2013. Its purpose is to compute dense correspondences between two images. In this work, we will use DeepMatching together with [DeepFlow](https://thoth.inrialpes.fr/src/deepflow) to calculate the optic flow of image pairs. When using the CPU version, on average it takes 35 seconds per image pair. To save your time, we provide the download link to all optic flow files of the sample video in the `demo` folder. If you need the GPU version of DeepMatching to speed up, then please follow these instructions.

# %% [markdown]
# ## Use Our Pre-Compiled Files (Recommended)
# For your convenience, we have compiled all files needed with Colab and tested on both Colab CPU and GPU.

# %% [markdown]
# ## Build From Scratch
# If Colab has updated the package versions and our pre-compiled files don't work, you may want to compile yourself. We'll leave necessary comments on how to modify files of an older version. So don't panic.
#
# You can test the correctness of the following steps with either CPU or GPU backend. This is because even if you have no access to NVIDIA driver (`nvidia-smi`) when using CPU, CUDA is still there in the file system.

# %% [markdown]
# #### Change CUDA Runtime Version
# Because the .cu files of DeepMatching used `cusparseScsrmm2`, which was removed since CUDA 11.0, we need to compile these files with previous version. We found that CUDA 10.1 would cause weird errors, but **CUDA 10.0** worked well. You can check CUDA runtime version by `!nvcc -V`.

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# The default CUDA runtime version should be 11.0. However, the GPU version of DeepMatching was released far before CUDA 11.0. We need to switch to an older CUDA version to compile CUDA files.

# %%
# !which nvcc
# Out:
# /usr/local/cuda/bin/nvcc

# %%
# !ls -ll /usr/local/ | grep cuda
# Out:
# lrwxrwxrwx  1 root root    9 Apr  7 13:29 cuda -> cuda-11.0
# drwxr-xr-x 16 root root 4096 Apr  7 13:24 cuda-10.0
# drwxr-xr-x 15 root root 4096 Apr  7 13:26 cuda-10.1
# drwxr-xr-x  1 root root 4096 Apr  7 13:28 cuda-11.0

# %% [markdown]
# `/usr/local/cuda` is simply a soft link, so we can make it link to the CUDA folder we want.

# %%
# !rm /usr/local/cuda
# !ln -s /usr/local/cuda-10.0  /usr/local/cuda

# %% [markdown]
# Now we successfully link `/usr/local/cuda` to `/usr/local/cuda-11.0`. We will switch back to CUDA 11.0 later to run TensorFlow 2.x.

# %% [markdown]
# #### Compile Caffe V1.0
# It seems that it has been about 2 years since the last commit to the GitHub [repo](https://github.com/BVLC/caffe). Among all the versions, version 1.0 works well. However, DeepMatching included an `.hpp` file that was removed and reconstructed since Caffe version `rc3`, so we need to modify these files when compiling DeepMatching later.
#
# We will use CUDA 10.0 and Python 2.7 to compile Caffe. We use Python 2.7 because DeepMatching GPU currently only supports Python 2.x.

# %% [markdown]
# First install some dependencies. This may take 3-7 minutes.

# %%
# References:
# https://github.com/mhmdghazal/Install-Caffe-using-Colab-/blob/master/Caffe_Work.ipynb
# http://caffe.berkeleyvision.org/install_apt.html
# http://caffe.berkeleyvision.org/installation.html#compilation
with open('/etc/apt/sources.list') as f:
  txt = f.read()
with open('/etc/apt/sources.list', 'w') as f:
  f.write(txt.replace('# deb-src','deb-src'))
# !apt update
# !apt upgrade

# !sudo apt build-dep caffe-cuda
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 http://archive.canonical.com/ubuntu bionic InRelease [10.2 kB]
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.canonical.com/ubuntu bionic/partner Sources [1,229 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe Sources [346 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted Sources [18.4 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/multiverse Sources [4,361 B]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main Sources [314 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main Sources [1,063 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,751 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe Sources [11.5 MB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/multiverse Sources [216 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/restricted Sources [5,823 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main Sources [636 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/universe Sources [572 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/restricted Sources [25.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse Sources [12.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,501 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [399 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,175 kB]
# Get:34 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [896 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-backports/main Sources [5,823 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-backports/universe Sources [5,759 B]
# Get:37 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [39.5 kB]
# Fetched 22.8 MB in 5s (4,521 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 35 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-140 linux-headers-4.15.0-140-generic r-cran-covr
#   r-cran-crosstalk r-cran-dt r-cran-htmlwidgets r-cran-later r-cran-lazyeval
#   r-cran-promises r-cran-rex
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   linux-headers-4.15.0-141 linux-headers-4.15.0-141-generic
# The following packages have been kept back:
#   libcudnn8 libcudnn8-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   binutils binutils-common binutils-x86-64-linux-gnu cuda-compat-11-0 gnupg2
#   libaudit-common libaudit1 libbinutils libc-bin libcublas-dev libcublas10
#   libcudnn7 libcudnn7-dev libldap-2.4-2 libldap-common libp11-kit0 libperl5.26
#   libsasl2-2 libsasl2-modules-db libzstd1 linux-headers-generic linux-libc-dev
#   openssl perl perl-base perl-modules-5.26 r-cran-dbplyr r-cran-devtools
#   r-cran-pkgload tar ubuntu-keyring
# 31 upgraded, 2 newly installed, 0 to remove and 4 not upgraded.
# Need to get 474 MB of archives.
# After this operation, 160 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  cuda-compat-11-0 450.102.04-1 [6,712 kB]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-dbplyr all 2.1.1-1cran1.1804.0 [768 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas10 10.2.3.254-1 [43.1 MB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libperl5.26 amd64 5.26.1-6ubuntu0.5 [3,534 kB]
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-pkgload all 1.2.1-1cran1.1804.0 [151 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl amd64 5.26.1-6ubuntu0.5 [201 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-base amd64 5.26.1-6ubuntu0.5 [1,391 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 perl-modules-5.26 all 5.26.1-6ubuntu0.5 [2,762 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tar amd64 1.29b-2ubuntu0.2 [234 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcublas-dev 10.2.3.254-1 [42.4 MB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libc-bin amd64 2.27-3ubuntu1.4 [643 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit-common all 1:2.8.2-1ubuntu1.1 [4,068 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaudit1 amd64 1:2.8.2-1ubuntu1.1 [38.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzstd1 amd64 1.3.3+dfsg-2ubuntu1.2 [189 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libp11-kit0 amd64 0.23.9-2ubuntu0.1 [187 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-keyring all 2018.09.18.1~18.04.2 [22.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssl amd64 1.1.1-1ubuntu2.1~18.04.9 [614 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.30-21ubuntu1~18.04.5 [1,839 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-common amd64 2.30-21ubuntu1~18.04.5 [197 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils amd64 2.30-21ubuntu1~18.04.5 [3,388 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbinutils amd64 2.30-21ubuntu1~18.04.5 [489 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [15.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.3 [49.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-141 all 4.15.0-141.145 [10.9 MB]
# Get:27 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 r-cran-devtools all 2.4.0-1cran1.1804.0 [377 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-141-generic amd64 4.15.0-141.145 [1,266 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.141.128 [2,484 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-141.145 [998 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gnupg2 all 2.2.4-1ubuntu1.4 [5,292 B]
# Get:32 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7-dev 7.6.5.32-1+cuda10.2 [165 MB]
# Get:33 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  libcudnn7 7.6.5.32-1+cuda10.2 [189 MB]
# Fetched 474 MB in 10s (48.4 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libperl5.26_5.26.1-6ubuntu0.5_amd64.deb ...
# Unpacking libperl5.26:amd64 (5.26.1-6ubuntu0.5) over (5.26.1-6ubuntu0.3) ...
# Preparing to unpack .../perl_5.26.1-6ubuntu0.5_amd64.deb ...
# Unpacking perl (5.26.1-6ubuntu0.5) over (5.26.1-6ubuntu0.3) ...
# Preparing to unpack .../perl-base_5.26.1-6ubuntu0.5_amd64.deb ...
# Unpacking perl-base (5.26.1-6ubuntu0.5) over (5.26.1-6ubuntu0.3) ...
# Setting up perl-base (5.26.1-6ubuntu0.5) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../perl-modules-5.26_5.26.1-6ubuntu0.5_all.deb ...
# Unpacking perl-modules-5.26 (5.26.1-6ubuntu0.5) over (5.26.1-6ubuntu0.3) ...
# Preparing to unpack .../tar_1.29b-2ubuntu0.2_amd64.deb ...
# Unpacking tar (1.29b-2ubuntu0.2) over (1.29b-2ubuntu0.1) ...
# Setting up tar (1.29b-2ubuntu0.2) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libc-bin_2.27-3ubuntu1.4_amd64.deb ...
# Unpacking libc-bin (2.27-3ubuntu1.4) over (2.27-3ubuntu1.2) ...
# Setting up libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libaudit-common_1%3a2.8.2-1ubuntu1.1_all.deb ...
# Unpacking libaudit-common (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit-common (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libaudit1_1%3a2.8.2-1ubuntu1.1_amd64.deb ...
# Unpacking libaudit1:amd64 (1:2.8.2-1ubuntu1.1) over (1:2.8.2-1ubuntu1) ...
# Setting up libaudit1:amd64 (1:2.8.2-1ubuntu1.1) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libzstd1_1.3.3+dfsg-2ubuntu1.2_amd64.deb ...
# Unpacking libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) over (1.3.3+dfsg-2ubuntu1.1) ...
# Setting up libzstd1:amd64 (1.3.3+dfsg-2ubuntu1.2) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libp11-kit0_0.23.9-2ubuntu0.1_amd64.deb ...
# Unpacking libp11-kit0:amd64 (0.23.9-2ubuntu0.1) over (0.23.9-2) ...
# Setting up libp11-kit0:amd64 (0.23.9-2ubuntu0.1) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../ubuntu-keyring_2018.09.18.1~18.04.2_all.deb ...
# Unpacking ubuntu-keyring (2018.09.18.1~18.04.2) over (2018.09.18.1~18.04.0) ...
# Setting up ubuntu-keyring (2018.09.18.1~18.04.2) ...
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../00-openssl_1.1.1-1ubuntu2.1~18.04.9_amd64.deb ...
# Unpacking openssl (1.1.1-1ubuntu2.1~18.04.9) over (1.1.1-1ubuntu2.1~18.04.6) ...
# Preparing to unpack .../01-binutils-x86-64-linux-gnu_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../02-binutils-common_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils-common:amd64 (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../03-binutils_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../04-libbinutils_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking libbinutils:amd64 (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../05-cuda-compat-11-0_450.102.04-1_amd64.deb ...
# Unpacking cuda-compat-11-0 (450.102.04-1) over (450.80.02-1) ...
# Preparing to unpack .../06-libcublas10_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas10 (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../07-libcublas-dev_10.2.3.254-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.3.254-1) over (10.2.1.243-1) ...
# Preparing to unpack .../08-libcudnn7-dev_7.6.5.32-1+cuda10.2_amd64.deb ...
# update-alternatives: removing manually selected alternative - switching libcudnn to auto mode
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v8.h to provide /usr/include/cudnn.h (libcudnn) in auto mode
# Unpacking libcudnn7-dev (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../09-libcudnn7_7.6.5.32-1+cuda10.2_amd64.deb ...
# Unpacking libcudnn7 (7.6.5.32-1+cuda10.2) over (7.6.5.32-1+cuda10.1) ...
# Preparing to unpack .../10-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../11-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.3_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) over (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Preparing to unpack .../12-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.6) ...
# Preparing to unpack .../13-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.6) ...
# Selecting previously unselected package linux-headers-4.15.0-141.
# Preparing to unpack .../14-linux-headers-4.15.0-141_4.15.0-141.145_all.deb ...
# Unpacking linux-headers-4.15.0-141 (4.15.0-141.145) ...
# Selecting previously unselected package linux-headers-4.15.0-141-generic.
# Preparing to unpack .../15-linux-headers-4.15.0-141-generic_4.15.0-141.145_amd64.deb ...
# Unpacking linux-headers-4.15.0-141-generic (4.15.0-141.145) ...
# Preparing to unpack .../16-linux-headers-generic_4.15.0.141.128_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.141.128) over (4.15.0.140.127) ...
# Preparing to unpack .../17-linux-libc-dev_4.15.0-141.145_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-141.145) over (4.15.0-118.119) ...
# Preparing to unpack .../18-r-cran-dbplyr_2.1.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-dbplyr (2.1.1-1cran1.1804.0) over (2.1.0-1cran1.1804.0) ...
# Preparing to unpack .../19-r-cran-pkgload_1.2.1-1cran1.1804.0_all.deb ...
# Unpacking r-cran-pkgload (1.2.1-1cran1.1804.0) over (1.2.0-1cran1.1804.0) ...
# Preparing to unpack .../20-r-cran-devtools_2.4.0-1cran1.1804.0_all.deb ...
# Unpacking r-cran-devtools (2.4.0-1cran1.1804.0) over (2.3.2-1cran1.1804.0) ...
# Preparing to unpack .../21-gnupg2_2.2.4-1ubuntu1.4_all.deb ...
# Unpacking gnupg2 (2.2.4-1ubuntu1.4) over (2.2.4-1ubuntu1.3) ...
# Setting up libcudnn7 (7.6.5.32-1+cuda10.2) ...
# Setting up linux-headers-4.15.0-141 (4.15.0-141.145) ...
# Setting up r-cran-pkgload (1.2.1-1cran1.1804.0) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up r-cran-devtools (2.4.0-1cran1.1804.0) ...
# Setting up cuda-compat-11-0 (450.102.04-1) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# Setting up linux-libc-dev:amd64 (4.15.0-141.145) ...
# Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.3) ...
# Setting up libcudnn7-dev (7.6.5.32-1+cuda10.2) ...
# update-alternatives: using /usr/include/x86_64-linux-gnu/cudnn_v7.h to provide /usr/include/cudnn.h (libcudnn) in manual mode
# Setting up perl-modules-5.26 (5.26.1-6ubuntu0.5) ...
# Setting up binutils-common:amd64 (2.30-21ubuntu1~18.04.5) ...
# Setting up gnupg2 (2.2.4-1ubuntu1.4) ...
# Setting up libcublas10 (10.2.3.254-1) ...
# Setting up libcublas-dev (10.2.3.254-1) ...
# Setting up libperl5.26:amd64 (5.26.1-6ubuntu0.5) ...
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up openssl (1.1.1-1ubuntu2.1~18.04.9) ...
# Setting up r-cran-dbplyr (2.1.1-1cran1.1804.0) ...
# Setting up linux-headers-4.15.0-141-generic (4.15.0-141.145) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-141-generic
#
# Kernel preparation unnecessary for this kernel.  Skipping...
# applying patch disable_fstack-clash-protection_fcf-protection.patch...patching file Kbuild
# Hunk #1 succeeded at 85 (offset 14 lines).
#
#
# Building module:
# cleaning build area...(bad exit status: 2)
# unset ARCH; [ ! -h /usr/bin/cc ] && export CC=/usr/bin/gcc; env NV_VERBOSE=1 'make' -j2 NV_EXCLUDE_BUILD_MODULES='' KERNEL_UNAME=4.15.0-141-generic IGNORE_XEN_PRESENCE=1 IGNORE_CC_MISMATCH=1 SYSSRC=/lib/modules/4.15.0-141-generic/build LD=/usr/bin/ld.bfd modules..............................................
# cleaning build area...(bad exit status: 2)
#
# DKMS: build completed.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-141-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-141-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-141-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-141-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
#    ...done.
# Setting up linux-headers-generic (4.15.0.141.128) ...
# Setting up libbinutils:amd64 (2.30-21ubuntu1~18.04.5) ...
# Setting up perl (5.26.1-6ubuntu0.5) ...
# Setting up binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.5) ...
# Setting up binutils (2.30-21ubuntu1~18.04.5) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Reading package lists... Done
# Picking 'caffe-contrib' as source package instead of 'caffe-cuda'
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-140 linux-headers-4.15.0-140-generic r-cran-covr
#   r-cran-crosstalk r-cran-dt r-cran-htmlwidgets r-cran-later r-cran-lazyeval
#   r-cran-promises r-cran-rex
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev bash-completion bc cpp-6 cython3
#   debhelper dh-autoreconf dh-strip-nondeterminism file fonts-lyx g++-6 gcc-6
#   gcc-6-base gettext gettext-base intltool-debian ipython3 libaccinj64-9.1
#   libarchive-zip-perl libasan3 libcublas9.1 libcudart9.1 libcufft9.1
#   libcufftw9.1 libcuinj64-9.1 libcurand9.1 libcusolver9.1 libcusparse9.1
#   libfile-stripnondeterminism-perl libgcc-6-dev libgflags-dev libgflags2.2
#   libgoogle-glog-dev libgoogle-glog0v5 libjs-jquery libjs-jquery-ui
#   libleveldb-dev libleveldb1v5 liblmdb-dev liblmdb0 libmagic-mgc libmagic1
#   libnppc9.1 libnppial9.1 libnppicc9.1 libnppicom9.1 libnppidei9.1 libnppif9.1
#   libnppig9.1 libnppim9.1 libnppist9.1 libnppisu9.1 libnppitc9.1 libnpps9.1
#   libnvblas9.1 libnvgraph9.1 libnvrtc9.1 libnvtoolsext1 libnvvm3
#   libprotobuf-dev libprotobuf-lite10 libprotoc-dev libsigsegv2 libsnappy-dev
#   libstdc++-6-dev libthrust-dev libtimedate-perl libtool m4 nvidia-cuda-dev
#   nvidia-cuda-toolkit nvidia-profiler po-debconf python-matplotlib-data
#   python3-cycler python3-dateutil python3-decorator python3-gflags
#   python3-h5py python3-ipython python3-ipython-genutils python3-leveldb
#   python3-matplotlib python3-networkx python3-nose python3-numpy
#   python3-pandas python3-pandas-lib python3-pexpect python3-pickleshare
#   python3-pil python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pydotplus python3-pygments python3-pyparsing
#   python3-pywt python3-scipy python3-simplegeneric python3-six python3-skimage
#   python3-skimage-lib python3-traitlets python3-tz python3-wcwidth
#   python3-yaml ttf-bitstream-vera
# 0 upgraded, 112 newly installed, 0 to remove and 4 not upgraded.
# Need to get 645 MB of archives.
# After this operation, 1,746 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-yaml amd64 3.12-1build2 [109 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 bash-completion all 1:2.8-1ubuntu1 [168 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 bc amd64 1.07.1-2 [86.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gcc-6-base amd64 6.5.0-2ubuntu1~18.04 [16.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 cpp-6 amd64 6.5.0-2ubuntu1~18.04 [6,396 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cython3 amd64 0.26.1-0.4 [1,925 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libasan3 amd64 6.5.0-2ubuntu1~18.04 [313 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libgcc-6-dev amd64 6.5.0-2ubuntu1~18.04 [2,308 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 gcc-6 amd64 6.5.0-2ubuntu1~18.04 [7,067 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 fonts-lyx all 2.2.4-0ubuntu0.18.04.1 [155 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libstdc++-6-dev amd64 6.5.0-2ubuntu1~18.04 [1,437 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 g++-6 amd64 6.5.0-2ubuntu1~18.04 [7,213 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-decorator all 4.1.2-1 [9,364 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-ptyprocess all 0.5.2-1 [12.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pexpect all 4.2.1-1 [42.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pickleshare all 0.7.4-2 [6,904 B]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-six all 1.11.0-2 [11.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-wcwidth all 0.1.7+dfsg1-1 [14.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-prompt-toolkit all 1.0.15-1 [163 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-pygments all 2.2.0+dfsg-1ubuntu0.2 [574 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-simplegeneric all 0.8.1-1 [11.5 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-ipython-genutils all 0.2.0-1 [20.9 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-traitlets all 4.3.2-1 [59.1 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-ipython all 5.5.0-1 [381 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ipython3 all 5.5.0-1 [5,304 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libaccinj64-9.1 amd64 9.1.85-3ubuntu1 [1,748 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcublas9.1 amd64 9.1.85-3ubuntu1 [25.0 MB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcudart9.1 amd64 9.1.85-3ubuntu1 [121 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcufft9.1 amd64 9.1.85-3ubuntu1 [76.1 MB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcufftw9.1 amd64 9.1.85-3ubuntu1 [131 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcuinj64-9.1 amd64 9.1.85-3ubuntu1 [1,878 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcurand9.1 amd64 9.1.85-3ubuntu1 [38.9 MB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcusolver9.1 amd64 9.1.85-3ubuntu1 [28.2 MB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcusparse9.1 amd64 9.1.85-3ubuntu1 [25.2 MB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags2.2 amd64 2.2.1-1 [72.4 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags-dev amd64 2.2.1-1 [86.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog0v5 amd64 0.3.5-1 [50.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog-dev amd64 0.3.5-1 [73.8 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libleveldb1v5 amd64 1.20-2 [136 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libleveldb-dev amd64 1.20-2 [177 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liblmdb0 amd64 0.9.21-1ubuntu0.1 [44.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liblmdb-dev amd64 0.9.21-1ubuntu0.1 [59.6 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppc9.1 amd64 9.1.85-3ubuntu1 [127 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppial9.1 amd64 9.1.85-3ubuntu1 [3,169 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppicc9.1 amd64 9.1.85-3ubuntu1 [1,376 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppicom9.1 amd64 9.1.85-3ubuntu1 [497 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppidei9.1 amd64 9.1.85-3ubuntu1 [1,673 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppif9.1 amd64 9.1.85-3ubuntu1 [20.9 MB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppig9.1 amd64 9.1.85-3ubuntu1 [9,960 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppim9.1 amd64 9.1.85-3ubuntu1 [2,295 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppist9.1 amd64 9.1.85-3ubuntu1 [4,910 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppisu9.1 amd64 9.1.85-3ubuntu1 [120 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnppitc9.1 amd64 9.1.85-3ubuntu1 [714 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnpps9.1 amd64 9.1.85-3ubuntu1 [2,568 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnvblas9.1 amd64 9.1.85-3ubuntu1 [132 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnvgraph9.1 amd64 9.1.85-3ubuntu1 [6,252 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnvrtc9.1 amd64 9.1.85-3ubuntu1 [6,309 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib-data all 2.1.1-2ubuntu3 [3,774 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-cycler all 0.10.0-1 [7,622 B]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-dateutil all 2.6.1-1 [52.3 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-gflags all 1.5.1-5 [35.6 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-numpy amd64 1:1.13.3-2ubuntu1 [1,943 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-h5py amd64 2.7.1-2 [631 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-leveldb amd64 0~svn68-3build3 [18.3 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pyparsing all 2.2.0+dfsg1-2 [52.2 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-tz all 2018.3-2 [25.1 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-matplotlib amd64 2.1.1-2ubuntu3 [3,907 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-networkx all 1.11-1ubuntu3 [606 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-nose all 1.3.7-3 [115 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pandas-lib amd64 0.22.0-4ubuntu1 [3,041 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pandas all 0.22.0-4ubuntu1 [2,765 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-pil amd64 5.1.0-1ubuntu0.5 [330 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-protobuf amd64 3.0.0-9.1ubuntu1 [262 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pydotplus all 2.0.2-2 [20.2 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pywt amd64 0.5.1-1.1ubuntu4 [932 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-scipy amd64 0.19.1-2ubuntu1 [9,619 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-skimage-lib amd64 0.13.1-2 [1,504 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-skimage all 0.13.1-2 [19.6 MB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnvtoolsext1 amd64 9.1.85-3ubuntu1 [31.3 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libnvvm3 amd64 9.1.85-3ubuntu1 [4,274 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotoc-dev amd64 3.0.0-9.1ubuntu1 [682 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy-dev amd64 1.1.7-1 [27.2 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libthrust-dev all 1.9.1~9.1.85-3ubuntu1 [461 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 nvidia-cuda-dev amd64 9.1.85-3ubuntu1 [263 MB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 nvidia-profiler amd64 9.1.85-3ubuntu1 [2,672 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 nvidia-cuda-toolkit amd64 9.1.85-3ubuntu1 [30.4 MB]
# Fetched 645 MB in 24s (26.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 112.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 190296 files and directories currently installed.)
# Preparing to unpack .../000-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../001-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../002-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package python3-yaml.
# Preparing to unpack .../003-python3-yaml_3.12-1build2_amd64.deb ...
# Unpacking python3-yaml (3.12-1build2) ...
# Selecting previously unselected package bash-completion.
# Preparing to unpack .../004-bash-completion_1%3a2.8-1ubuntu1_all.deb ...
# Unpacking bash-completion (1:2.8-1ubuntu1) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../005-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../006-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../007-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../008-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../009-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../010-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../011-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package bc.
# Preparing to unpack .../012-bc_1.07.1-2_amd64.deb ...
# Unpacking bc (1.07.1-2) ...
# Selecting previously unselected package gcc-6-base:amd64.
# Preparing to unpack .../013-gcc-6-base_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking gcc-6-base:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package cpp-6.
# Preparing to unpack .../014-cpp-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking cpp-6 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package cython3.
# Preparing to unpack .../015-cython3_0.26.1-0.4_amd64.deb ...
# Unpacking cython3 (0.26.1-0.4) ...
# Selecting previously unselected package libasan3:amd64.
# Preparing to unpack .../016-libasan3_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libasan3:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package libgcc-6-dev:amd64.
# Preparing to unpack .../017-libgcc-6-dev_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libgcc-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package gcc-6.
# Preparing to unpack .../018-gcc-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking gcc-6 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../019-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../020-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../021-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../022-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../023-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../024-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../025-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../026-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../027-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../028-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../029-fonts-lyx_2.2.4-0ubuntu0.18.04.1_all.deb ...
# Unpacking fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libstdc++-6-dev:amd64.
# Preparing to unpack .../030-libstdc++-6-dev_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking libstdc++-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package g++-6.
# Preparing to unpack .../031-g++-6_6.5.0-2ubuntu1~18.04_amd64.deb ...
# Unpacking g++-6 (6.5.0-2ubuntu1~18.04) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../032-python3-decorator_4.1.2-1_all.deb ...
# Unpacking python3-decorator (4.1.2-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../033-python3-ptyprocess_0.5.2-1_all.deb ...
# Unpacking python3-ptyprocess (0.5.2-1) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../034-python3-pexpect_4.2.1-1_all.deb ...
# Unpacking python3-pexpect (4.2.1-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../035-python3-pickleshare_0.7.4-2_all.deb ...
# Unpacking python3-pickleshare (0.7.4-2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../036-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../037-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../038-python3-wcwidth_0.1.7+dfsg1-1_all.deb ...
# Unpacking python3-wcwidth (0.1.7+dfsg1-1) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../039-python3-prompt-toolkit_1.0.15-1_all.deb ...
# Unpacking python3-prompt-toolkit (1.0.15-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../040-python3-pygments_2.2.0+dfsg-1ubuntu0.2_all.deb ...
# Unpacking python3-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package python3-simplegeneric.
# Preparing to unpack .../041-python3-simplegeneric_0.8.1-1_all.deb ...
# Unpacking python3-simplegeneric (0.8.1-1) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../042-python3-ipython-genutils_0.2.0-1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../043-python3-traitlets_4.3.2-1_all.deb ...
# Unpacking python3-traitlets (4.3.2-1) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../044-python3-ipython_5.5.0-1_all.deb ...
# Unpacking python3-ipython (5.5.0-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../045-ipython3_5.5.0-1_all.deb ...
# Unpacking ipython3 (5.5.0-1) ...
# Selecting previously unselected package libaccinj64-9.1:amd64.
# Preparing to unpack .../046-libaccinj64-9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libaccinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcublas9.1:amd64.
# Preparing to unpack .../047-libcublas9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcublas9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcudart9.1:amd64.
# Preparing to unpack .../048-libcudart9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcudart9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcufft9.1:amd64.
# Preparing to unpack .../049-libcufft9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcufft9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcufftw9.1:amd64.
# Preparing to unpack .../050-libcufftw9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcufftw9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcuinj64-9.1:amd64.
# Preparing to unpack .../051-libcuinj64-9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcuinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcurand9.1:amd64.
# Preparing to unpack .../052-libcurand9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcurand9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcusolver9.1:amd64.
# Preparing to unpack .../053-libcusolver9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcusolver9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcusparse9.1:amd64.
# Preparing to unpack .../054-libcusparse9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcusparse9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../055-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgflags-dev.
# Preparing to unpack .../056-libgflags-dev_2.2.1-1_amd64.deb ...
# Unpacking libgflags-dev (2.2.1-1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../057-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../058-libgoogle-glog-dev_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.3.5-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../059-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../060-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package libleveldb1v5:amd64.
# Preparing to unpack .../061-libleveldb1v5_1.20-2_amd64.deb ...
# Unpacking libleveldb1v5:amd64 (1.20-2) ...
# Selecting previously unselected package libleveldb-dev:amd64.
# Preparing to unpack .../062-libleveldb-dev_1.20-2_amd64.deb ...
# Unpacking libleveldb-dev:amd64 (1.20-2) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../063-liblmdb0_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package liblmdb-dev:amd64.
# Preparing to unpack .../064-liblmdb-dev_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libnppc9.1:amd64.
# Preparing to unpack .../065-libnppc9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppc9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppial9.1:amd64.
# Preparing to unpack .../066-libnppial9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppial9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppicc9.1:amd64.
# Preparing to unpack .../067-libnppicc9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppicc9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppicom9.1:amd64.
# Preparing to unpack .../068-libnppicom9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppicom9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppidei9.1:amd64.
# Preparing to unpack .../069-libnppidei9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppidei9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppif9.1:amd64.
# Preparing to unpack .../070-libnppif9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppif9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppig9.1:amd64.
# Preparing to unpack .../071-libnppig9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppig9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppim9.1:amd64.
# Preparing to unpack .../072-libnppim9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppim9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppist9.1:amd64.
# Preparing to unpack .../073-libnppist9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppist9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppisu9.1:amd64.
# Preparing to unpack .../074-libnppisu9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppisu9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnppitc9.1:amd64.
# Preparing to unpack .../075-libnppitc9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnppitc9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnpps9.1:amd64.
# Preparing to unpack .../076-libnpps9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnpps9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnvblas9.1:amd64.
# Preparing to unpack .../077-libnvblas9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvblas9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnvgraph9.1:amd64.
# Preparing to unpack .../078-libnvgraph9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvgraph9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnvrtc9.1:amd64.
# Preparing to unpack .../079-libnvrtc9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvrtc9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../080-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../081-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../082-python-matplotlib-data_2.1.1-2ubuntu3_all.deb ...
# Unpacking python-matplotlib-data (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../083-python3-cycler_0.10.0-1_all.deb ...
# Unpacking python3-cycler (0.10.0-1) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../084-python3-dateutil_2.6.1-1_all.deb ...
# Unpacking python3-dateutil (2.6.1-1) ...
# Selecting previously unselected package python3-gflags.
# Preparing to unpack .../085-python3-gflags_1.5.1-5_all.deb ...
# Unpacking python3-gflags (1.5.1-5) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../086-python3-numpy_1%3a1.13.3-2ubuntu1_amd64.deb ...
# Unpacking python3-numpy (1:1.13.3-2ubuntu1) ...
# Selecting previously unselected package python3-h5py.
# Preparing to unpack .../087-python3-h5py_2.7.1-2_amd64.deb ...
# Unpacking python3-h5py (2.7.1-2) ...
# Selecting previously unselected package python3-leveldb.
# Preparing to unpack .../088-python3-leveldb_0~svn68-3build3_amd64.deb ...
# Unpacking python3-leveldb (0~svn68-3build3) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../089-python3-pyparsing_2.2.0+dfsg1-2_all.deb ...
# Unpacking python3-pyparsing (2.2.0+dfsg1-2) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../090-python3-tz_2018.3-2_all.deb ...
# Unpacking python3-tz (2018.3-2) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../091-python3-matplotlib_2.1.1-2ubuntu3_amd64.deb ...
# Unpacking python3-matplotlib (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python3-networkx.
# Preparing to unpack .../092-python3-networkx_1.11-1ubuntu3_all.deb ...
# Unpacking python3-networkx (1.11-1ubuntu3) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../093-python3-nose_1.3.7-3_all.deb ...
# Unpacking python3-nose (1.3.7-3) ...
# Selecting previously unselected package python3-pandas-lib.
# Preparing to unpack .../094-python3-pandas-lib_0.22.0-4ubuntu1_amd64.deb ...
# Unpacking python3-pandas-lib (0.22.0-4ubuntu1) ...
# Selecting previously unselected package python3-pandas.
# Preparing to unpack .../095-python3-pandas_0.22.0-4ubuntu1_all.deb ...
# Unpacking python3-pandas (0.22.0-4ubuntu1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../096-python3-pil_5.1.0-1ubuntu0.5_amd64.deb ...
# Unpacking python3-pil:amd64 (5.1.0-1ubuntu0.5) ...
# Selecting previously unselected package python3-protobuf.
# Preparing to unpack .../097-python3-protobuf_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking python3-protobuf (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package python3-pydotplus.
# Preparing to unpack .../098-python3-pydotplus_2.0.2-2_all.deb ...
# Unpacking python3-pydotplus (2.0.2-2) ...
# Selecting previously unselected package python3-pywt.
# Preparing to unpack .../099-python3-pywt_0.5.1-1.1ubuntu4_amd64.deb ...
# Unpacking python3-pywt (0.5.1-1.1ubuntu4) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../100-python3-scipy_0.19.1-2ubuntu1_amd64.deb ...
# Unpacking python3-scipy (0.19.1-2ubuntu1) ...
# Selecting previously unselected package python3-skimage-lib:amd64.
# Preparing to unpack .../101-python3-skimage-lib_0.13.1-2_amd64.deb ...
# Unpacking python3-skimage-lib:amd64 (0.13.1-2) ...
# Selecting previously unselected package python3-skimage.
# Preparing to unpack .../102-python3-skimage_0.13.1-2_all.deb ...
# Unpacking python3-skimage (0.13.1-2) ...
# Selecting previously unselected package libnvtoolsext1:amd64.
# Preparing to unpack .../103-libnvtoolsext1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libnvvm3:amd64.
# Preparing to unpack .../104-libnvvm3_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvvm3:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../105-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libprotoc-dev:amd64.
# Preparing to unpack .../106-libprotoc-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotoc-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libsnappy-dev:amd64.
# Preparing to unpack .../107-libsnappy-dev_1.1.7-1_amd64.deb ...
# Unpacking libsnappy-dev:amd64 (1.1.7-1) ...
# Selecting previously unselected package libthrust-dev.
# Preparing to unpack .../108-libthrust-dev_1.9.1~9.1.85-3ubuntu1_all.deb ...
# Unpacking libthrust-dev (1.9.1~9.1.85-3ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-dev.
# Preparing to unpack .../109-nvidia-cuda-dev_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev (9.1.85-3ubuntu1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../110-nvidia-profiler_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking nvidia-profiler (9.1.85-3ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../111-nvidia-cuda-toolkit_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (9.1.85-3ubuntu1) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libcufft9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-yaml (3.12-1build2) ...
# Setting up libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcusparse9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-pickleshare (0.7.4-2) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up python3-pil:amd64 (5.1.0-1ubuntu0.5) ...
# Setting up python3-simplegeneric (0.8.1-1) ...
# Setting up libgflags-dev (2.2.1-1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libthrust-dev (1.9.1~9.1.85-3ubuntu1) ...
# Setting up liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up python3-numpy (1:1.13.3-2ubuntu1) ...
# Setting up bash-completion (1:2.8-1ubuntu1) ...
# Setting up gcc-6-base:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up libcuinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-six (1.11.0-2) ...
# Setting up python3-pyparsing (2.2.0+dfsg1-2) ...
# Setting up python3-cycler (0.10.0-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python3-gflags (1.5.1-5) ...
# update-alternatives: using /usr/bin/python3-gflags2man to provide /usr/bin/gflags2man (gflags2man) in auto mode
# Setting up libleveldb1v5:amd64 (1.20-2) ...
# Setting up python3-skimage-lib:amd64 (0.13.1-2) ...
# Setting up python3-pandas-lib (0.22.0-4ubuntu1) ...
# Setting up libnppc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libaccinj64-9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up python3-wcwidth (0.1.7+dfsg1-1) ...
# Setting up libcurand9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvrtc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-protobuf (3.0.0-9.1ubuntu1) ...
# Setting up libnppitc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppif9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libsnappy-dev:amd64 (1.1.7-1) ...
# Setting up python3-ipython-genutils (0.2.0-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up python3-nose (1.3.7-3) ...
# Setting up libgoogle-glog0v5 (0.3.5-1) ...
# Setting up libnvvm3:amd64 (9.1.85-3ubuntu1) ...
# Setting up libjs-jquery-ui (1.12.1+dfsg-5) ...
# Setting up libcublas9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up ttf-bitstream-vera (1.10-8) ...
# Setting up cython3 (0.26.1-0.4) ...
# Setting up liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up cpp-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up python3-pywt (0.5.1-1.1ubuntu4) ...
# Setting up libcufftw9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libcudart9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up bc (1.07.1-2) ...
# Setting up libnppim9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libcusolver9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvblas9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-decorator (4.1.2-1) ...
# Setting up python3-traitlets (4.3.2-1) ...
# Setting up python3-ptyprocess (0.5.2-1) ...
# Setting up python3-tz (2018.3-2) ...
# Setting up python3-leveldb (0~svn68-3build3) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up python3-dateutil (2.6.1-1) ...
# Setting up libnppidei9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up python3-h5py (2.7.1-2) ...
# Setting up fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Setting up libnppial9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up python3-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# Setting up nvidia-profiler (9.1.85-3ubuntu1) ...
# Setting up libasan3:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up python3-scipy (0.19.1-2ubuntu1) ...
# Setting up libgcc-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up python3-prompt-toolkit (1.0.15-1) ...
# Setting up libstdc++-6-dev:amd64 (6.5.0-2ubuntu1~18.04) ...
# Setting up python-matplotlib-data (2.1.1-2ubuntu3) ...
# Setting up libnppicom9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up python3-pydotplus (2.0.2-2) ...
# Setting up libnppisu9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libnpps9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libleveldb-dev:amd64 (1.20-2) ...
# Setting up libgoogle-glog-dev (0.3.5-1) ...
# Setting up libnppicc9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnppist9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up libnppig9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvgraph9.1:amd64 (9.1.85-3ubuntu1) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up nvidia-cuda-dev (9.1.85-3ubuntu1) ...
# Setting up gcc-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up g++-6 (6.5.0-2ubuntu1~18.04) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up python3-pexpect (4.2.1-1) ...
# Setting up python3-networkx (1.11-1ubuntu3) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up nvidia-cuda-toolkit (9.1.85-3ubuntu1) ...
# Setting up python3-pandas (0.22.0-4ubuntu1) ...
# Setting up libprotoc-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up python3-matplotlib (2.1.1-2ubuntu3) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up python3-ipython (5.5.0-1) ...
# Setting up python3-skimage (0.13.1-2) ...
# Setting up ipython3 (5.5.0-1) ...
# Setting up dh-autoreconf (17) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %% [markdown]
# Next, clone the repo.

# %%
# %cd /content/
# !git clone https://github.com/BVLC/caffe.git
# %cd /content/caffe
# !git tag -l  # show all tags (versions)
# !git checkout tags/1.0  # use version 1.0 (the latest version)
# !!cp Makefile.config.example Makefile.config
# Out:
# /content
# Cloning into 'caffe'...
# remote: Enumerating objects: 65274, done.
# remote: Total 65274 (delta 0), reused 0 (delta 0), pack-reused 65274
# Receiving objects: 100% (65274/65274), 74.14 MiB | 22.77 MiB/s, done.
# Resolving deltas: 100% (41249/41249), done.
# /content/caffe
# 1.0
# acm-mm-oss
# bsd
# rc
# rc2
# rc3
# rc4
# rc5
# rcnn-release
# v0.1
# v0.9
# v0.99
# v0.999
# v0.9999
# Note: checking out 'tags/1.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at eeebdab1 Merge pull request #5530 from willyd/nccl-py3
# []

# %% [markdown]
# Before we compile Caffe, we need to modify `Makefile.config`.
# We made the following changes.
#
#
# *   Uncomment line 12-14. Otherwise, there are errors. (Seems that you need to insall OpenCV.)
# *   Specify CUDA_DIR in line 31. Remember that we have changed the soft link `/usr/local/cuda`. But to prevent any issues, we carefully specify the folder name with CUDA version (`cuda-10.0`).
# *   Modify CUDA_ARCH in line 40. With a free Colab GPU, you may meet K80, P4, and T4 (use `!nvidia-smi` to check the GPU version). If you have access to other GPUs, refer to this article [Matching CUDA arch and CUDA gencode for various NVIDIA architectures](https://arnon.dk/matching-sm-architectures-arch-and-gencode-for-various-nvidia-cards/)
# for more information.
# *   Modify PYTHON_INCLUDE in line 74. You can use `!python2 -c "import numpy; print(numpy.get_include())"` to find the correct path.
# *   Add hdf5 files in line 99-100. You can use `!find /usr -name "hdf5"` to find the include and lib path. Refer to this blog [Caffe fatal error: hdf5.h: No such file or directory error solution](https://programmerah.com/caffe-fatal-error-hdf5-h-no-such-file-or-directory-error-solution-6298/) for more information.
#
# Run the following cell to rewrite `Makefile.config`.

# %%
# %%writefile /content/caffe/Makefile.config
# ## Refer to http://caffe.berkeleyvision.org/installation.html
# # Contributions simplifying and improving our build system are welcome!
#
# # cuDNN acceleration switch (uncomment to build with cuDNN).
# # USE_CUDNN := 1
#
# # CPU-only switch (uncomment to build without GPU support).
# # CPU_ONLY := 1
#
# # uncomment to disable IO dependencies and corresponding data layers
# USE_OPENCV := 0
# USE_LEVELDB := 0
# USE_LMDB := 0
# # This code is taken from https://github.com/sh1r0/caffe-android-lib
# # USE_HDF5 := 0
#
# # uncomment to allow MDB_NOLOCK when reading LMDB files (only if necessary)
# #	You should not set this flag if you will be reading LMDBs with any
# #	possibility of simultaneous read and write
# # ALLOW_LMDB_NOLOCK := 1
#
# # Uncomment if you're using OpenCV 3
# # OPENCV_VERSION := 3
#
# # To customize your choice of compiler, uncomment and set the following.
# # N.B. the default for Linux is g++ and the default for OSX is clang++
# # CUSTOM_CXX := g++
#
# # CUDA directory contains bin/ and lib/ directories that we need.
# CUDA_DIR := /usr/local/cuda-10.0
# # On Ubuntu 14.04, if cuda tools are installed via
# # "sudo apt-get install nvidia-cuda-toolkit" then use this instead:
# # CUDA_DIR := /usr
#
# # CUDA architecture setting: going with all of them.
# # For CUDA < 6.0, comment the *_50 through *_61 lines for compatibility.
# # For CUDA < 8.0, comment the *_60 and *_61 lines for compatibility.
# # For CUDA >= 9.0, comment the *_20 and *_21 lines for compatibility.
# CUDA_ARCH := #-gencode arch=compute_20,code=sm_20 \
# 		#-gencode arch=compute_20,code=sm_21 \
# 		#-gencode arch=compute_30,code=sm_30 \
# 		-gencode arch=compute_35,code=sm_35 \
# 		-gencode arch=compute_50,code=sm_50 \
# 		-gencode arch=compute_52,code=sm_52 \
# 		-gencode arch=compute_60,code=sm_60 \
# 		-gencode arch=compute_61,code=sm_61 \
# 		-gencode arch=compute_61,code=compute_61 \
#         -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # BLAS choice:
# # atlas for ATLAS (default)
# # mkl for MKL
# # open for OpenBlas
# BLAS := atlas
# # Custom (MKL/ATLAS/OpenBLAS) include and lib directories.
# # Leave commented to accept the defaults for your choice of BLAS
# # (which should work)!
# # BLAS_INCLUDE := /path/to/your/blas
# # BLAS_LIB := /path/to/your/blas
#
# # Homebrew puts openblas in a directory that is not on the standard search path
# # BLAS_INCLUDE := $(shell brew --prefix openblas)/include
# # BLAS_LIB := $(shell brew --prefix openblas)/lib
#
# # This is required only if you will compile the matlab interface.
# # MATLAB directory should contain the mex binary in /bin.
# # MATLAB_DIR := /usr/local
# # MATLAB_DIR := /Applications/MATLAB_R2012b.app
#
# # NOTE: this is required only if you will compile the python interface.
# # We need to be able to find Python.h and numpy/arrayobject.h.
# PYTHON_INCLUDE := /usr/include/python2.7 \
# 		/usr/local/lib/python2.7/dist-packages/numpy/core/include
# # Anaconda Python distribution is quite popular. Include path:
# # Verify anaconda location, sometimes it's in root.
# # ANACONDA_HOME := $(HOME)/anaconda
# # PYTHON_INCLUDE := $(ANACONDA_HOME)/include \
# 		# $(ANACONDA_HOME)/include/python2.7 \
# 		# $(ANACONDA_HOME)/lib/python2.7/site-packages/numpy/core/include
#
# # Uncomment to use Python 3 (default is Python 2)
# # PYTHON_LIBRARIES := boost_python3 python3.5m
# # PYTHON_INCLUDE := /usr/include/python3.5m \
# #                 /usr/lib/python3.5/dist-packages/numpy/core/include
#
# # We need to be able to find libpythonX.X.so or .dylib.
# PYTHON_LIB := /usr/lib
# # PYTHON_LIB := $(ANACONDA_HOME)/lib
#
# # Homebrew installs numpy in a non standard path (keg only)
# # PYTHON_INCLUDE += $(dir $(shell python -c 'import numpy.core; print(numpy.core.__file__)'))/include
# # PYTHON_LIB += $(shell brew --prefix numpy)/lib
#
# # Uncomment to support layers written in Python (will link against Python libs)
# # WITH_PYTHON_LAYER := 1
#
# # Whatever else you find you need goes here.
# INCLUDE_DIRS := $(PYTHON_INCLUDE) /usr/local/include /usr/include/hdf5/serial
# LIBRARY_DIRS := $(PYTHON_LIB) /usr/local/lib /usr/lib /usr/lib/x86_64-linux-gnu/hdf5/serial
#
# # If Homebrew is installed at a non standard location (for example your home directory) and you use it for general dependencies
# # INCLUDE_DIRS += $(shell brew --prefix)/include
# # LIBRARY_DIRS += $(shell brew --prefix)/lib
#
# # NCCL acceleration switch (uncomment to build with NCCL)
# # https://github.com/NVIDIA/nccl (last tested version: v1.2.3-1+cuda8.0)
# # USE_NCCL := 1
#
# # Uncomment to use `pkg-config` to specify OpenCV library paths.
# # (Usually not necessary -- OpenCV libraries are normally installed in one of the above $LIBRARY_DIRS.)
# # USE_PKG_CONFIG := 1
#
# # N.B. both build and distribute dirs are cleared on `make clean`
# BUILD_DIR := build
# DISTRIBUTE_DIR := distribute
#
# # Uncomment for debugging. Does not work on OSX due to https://github.com/BVLC/caffe/issues/171
# # DEBUG := 1
#
# # The ID of the GPU that 'make runtest' will use to run unit tests.
# TEST_GPUID := 0
#
# # enable pretty build (comment to see full commands)
# Q ?= @
# Out:
# Overwriting /content/caffe/Makefile.config

# %% [markdown]
# All set! Now let's compile Caffe. The whole process may take 6-8 minutes.

# %%
# 6-7 minutes
# %cd /content/caffe/
# !sudo make all -j 2  # 2 processes
# Out:
# /content/caffe
# CXX src/caffe/blob.cpp
# PROTOC src/caffe/proto/caffe.proto
# CXX src/caffe/solvers/adam_solver.cpp
# CXX src/caffe/solvers/sgd_solver.cpp
# CXX src/caffe/solvers/rmsprop_solver.cpp
# CXX src/caffe/solvers/nesterov_solver.cpp
# CXX src/caffe/solvers/adagrad_solver.cpp
# CXX src/caffe/solvers/adadelta_solver.cpp
# CXX src/caffe/parallel.cpp
# CXX src/caffe/syncedmem.cpp
# CXX src/caffe/data_transformer.cpp
# CXX src/caffe/layer.cpp
# CXX src/caffe/util/upgrade_proto.cpp
# CXX src/caffe/util/hdf5.cpp
# CXX src/caffe/util/benchmark.cpp
# CXX src/caffe/util/math_functions.cpp
# CXX src/caffe/util/signal_handler.cpp
# CXX src/caffe/util/db_leveldb.cpp
# CXX src/caffe/util/cudnn.cpp
# CXX src/caffe/util/io.cpp
# CXX src/caffe/util/insert_splits.cpp
# CXX src/caffe/util/db.cpp
# CXX src/caffe/util/db_lmdb.cpp
# CXX src/caffe/util/im2col.cpp
# CXX src/caffe/util/blocking_queue.cpp
# CXX src/caffe/common.cpp
# CXX src/caffe/net.cpp
# CXX src/caffe/layer_factory.cpp
# CXX src/caffe/layers/batch_norm_layer.cpp
# CXX src/caffe/layers/tanh_layer.cpp
# CXX src/caffe/layers/deconv_layer.cpp
# CXX src/caffe/layers/multinomial_logistic_loss_layer.cpp
# CXX src/caffe/layers/concat_layer.cpp
# CXX src/caffe/layers/elu_layer.cpp
# CXX src/caffe/layers/sigmoid_layer.cpp
# CXX src/caffe/layers/parameter_layer.cpp
# CXX src/caffe/layers/window_data_layer.cpp
# CXX src/caffe/layers/softmax_layer.cpp
# CXX src/caffe/layers/conv_layer.cpp
# CXX src/caffe/layers/cudnn_pooling_layer.cpp
# CXX src/caffe/layers/recurrent_layer.cpp
# CXX src/caffe/layers/hdf5_data_layer.cpp
# CXX src/caffe/layers/cudnn_relu_layer.cpp
# CXX src/caffe/layers/euclidean_loss_layer.cpp
# CXX src/caffe/layers/im2col_layer.cpp
# CXX src/caffe/layers/pooling_layer.cpp
# CXX src/caffe/layers/embed_layer.cpp
# CXX src/caffe/layers/argmax_layer.cpp
# CXX src/caffe/layers/absval_layer.cpp
# CXX src/caffe/layers/cudnn_lcn_layer.cpp
# CXX src/caffe/layers/accuracy_layer.cpp
# CXX src/caffe/layers/tile_layer.cpp
# CXX src/caffe/layers/cudnn_sigmoid_layer.cpp
# CXX src/caffe/layers/neuron_layer.cpp
# CXX src/caffe/layers/sigmoid_cross_entropy_loss_layer.cpp
# CXX src/caffe/layers/scale_layer.cpp
# CXX src/caffe/layers/spp_layer.cpp
# CXX src/caffe/layers/infogain_loss_layer.cpp
# CXX src/caffe/layers/hdf5_output_layer.cpp
# CXX src/caffe/layers/hinge_loss_layer.cpp
# CXX src/caffe/layers/lrn_layer.cpp
# CXX src/caffe/layers/eltwise_layer.cpp
# CXX src/caffe/layers/cudnn_conv_layer.cpp
# CXX src/caffe/layers/flatten_layer.cpp
# CXX src/caffe/layers/slice_layer.cpp
# CXX src/caffe/layers/base_data_layer.cpp
# CXX src/caffe/layers/lstm_unit_layer.cpp
# CXX src/caffe/layers/reshape_layer.cpp
# CXX src/caffe/layers/threshold_layer.cpp
# CXX src/caffe/layers/bnll_layer.cpp
# CXX src/caffe/layers/prelu_layer.cpp
# CXX src/caffe/layers/reduction_layer.cpp
# CXX src/caffe/layers/filter_layer.cpp
# CXX src/caffe/layers/rnn_layer.cpp
# CXX src/caffe/layers/relu_layer.cpp
# CXX src/caffe/layers/silence_layer.cpp
# CXX src/caffe/layers/softmax_loss_layer.cpp
# CXX src/caffe/layers/inner_product_layer.cpp
# CXX src/caffe/layers/bias_layer.cpp
# CXX src/caffe/layers/lstm_layer.cpp
# CXX src/caffe/layers/crop_layer.cpp
# CXX src/caffe/layers/batch_reindex_layer.cpp
# CXX src/caffe/layers/image_data_layer.cpp
# CXX src/caffe/layers/contrastive_loss_layer.cpp
# CXX src/caffe/layers/exp_layer.cpp
# CXX src/caffe/layers/cudnn_tanh_layer.cpp
# CXX src/caffe/layers/dropout_layer.cpp
# CXX src/caffe/layers/cudnn_softmax_layer.cpp
# CXX src/caffe/layers/log_layer.cpp
# CXX src/caffe/layers/data_layer.cpp
# CXX src/caffe/layers/power_layer.cpp
# CXX src/caffe/layers/input_layer.cpp
# CXX src/caffe/layers/mvn_layer.cpp
# CXX src/caffe/layers/memory_data_layer.cpp
# CXX src/caffe/layers/base_conv_layer.cpp
# CXX src/caffe/layers/split_layer.cpp
# CXX src/caffe/layers/loss_layer.cpp
# CXX src/caffe/layers/dummy_data_layer.cpp
# CXX src/caffe/layers/cudnn_lrn_layer.cpp
# CXX src/caffe/internal_thread.cpp
# CXX src/caffe/solver.cpp
# NVCC src/caffe/solvers/adagrad_solver.cu
# NVCC src/caffe/solvers/adam_solver.cu
# NVCC src/caffe/solvers/nesterov_solver.cu
# NVCC src/caffe/solvers/adadelta_solver.cu
# NVCC src/caffe/solvers/rmsprop_solver.cu
# NVCC src/caffe/solvers/sgd_solver.cu
# NVCC src/caffe/util/math_functions.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda-10.0/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda-10.0/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# NVCC src/caffe/util/im2col.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda-10.0/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda-10.0/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# NVCC src/caffe/layers/hdf5_data_layer.cu
# NVCC src/caffe/layers/embed_layer.cu
# NVCC src/caffe/layers/inner_product_layer.cu
# NVCC src/caffe/layers/batch_norm_layer.cu
# NVCC src/caffe/layers/relu_layer.cu
# NVCC src/caffe/layers/eltwise_layer.cu
# NVCC src/caffe/layers/bias_layer.cu
# NVCC src/caffe/layers/im2col_layer.cu
# NVCC src/caffe/layers/absval_layer.cu
# NVCC src/caffe/layers/exp_layer.cu
# NVCC src/caffe/layers/elu_layer.cu
# NVCC src/caffe/layers/euclidean_loss_layer.cu
# NVCC src/caffe/layers/sigmoid_cross_entropy_loss_layer.cu
# NVCC src/caffe/layers/lstm_unit_layer.cu
# NVCC src/caffe/layers/cudnn_pooling_layer.cu
# NVCC src/caffe/layers/softmax_loss_layer.cu
# NVCC src/caffe/layers/crop_layer.cu
# NVCC src/caffe/layers/prelu_layer.cu
# NVCC src/caffe/layers/filter_layer.cu
# NVCC src/caffe/layers/cudnn_conv_layer.cu
# NVCC src/caffe/layers/cudnn_tanh_layer.cu
# NVCC src/caffe/layers/cudnn_sigmoid_layer.cu
# NVCC src/caffe/layers/slice_layer.cu
# NVCC src/caffe/layers/threshold_layer.cu
# NVCC src/caffe/layers/contrastive_loss_layer.cu
# NVCC src/caffe/layers/sigmoid_layer.cu
# NVCC src/caffe/layers/silence_layer.cu
# NVCC src/caffe/layers/batch_reindex_layer.cu
# NVCC src/caffe/layers/cudnn_lrn_layer.cu
# NVCC src/caffe/layers/scale_layer.cu
# NVCC src/caffe/layers/lrn_layer.cu
# NVCC src/caffe/layers/recurrent_layer.cu
# NVCC src/caffe/layers/dropout_layer.cu
# NVCC src/caffe/layers/split_layer.cu
# NVCC src/caffe/layers/cudnn_relu_layer.cu
# NVCC src/caffe/layers/tile_layer.cu
# NVCC src/caffe/layers/power_layer.cu
# NVCC src/caffe/layers/log_layer.cu
# NVCC src/caffe/layers/bnll_layer.cu
# NVCC src/caffe/layers/hdf5_output_layer.cu
# NVCC src/caffe/layers/conv_layer.cu
# NVCC src/caffe/layers/cudnn_lcn_layer.cu
# NVCC src/caffe/layers/reduction_layer.cu
# NVCC src/caffe/layers/cudnn_softmax_layer.cu
# NVCC src/caffe/layers/mvn_layer.cu
# NVCC src/caffe/layers/pooling_layer.cu
# NVCC src/caffe/layers/deconv_layer.cu
# NVCC src/caffe/layers/base_data_layer.cu
# NVCC src/caffe/layers/concat_layer.cu
# NVCC src/caffe/layers/tanh_layer.cu
# NVCC src/caffe/layers/softmax_layer.cu
# CXX tools/train_net.cpp
# CXX tools/test_net.cpp
# CXX tools/upgrade_net_proto_binary.cpp
# CXX tools/net_speed_benchmark.cpp
# CXX tools/device_query.cpp
# CXX tools/compute_image_mean.cpp
# CXX tools/caffe.cpp
# CXX tools/upgrade_solver_proto_text.cpp
# CXX tools/finetune_net.cpp
# CXX tools/convert_imageset.cpp
# CXX tools/extract_features.cpp
# CXX tools/upgrade_net_proto_text.cpp
# CXX examples/mnist/convert_mnist_data.cpp
# CXX examples/cpp_classification/classification.cpp
# CXX examples/cifar10/convert_cifar_data.cpp
# CXX examples/siamese/convert_mnist_siamese_data.cpp
# CXX .build_release/src/caffe/proto/caffe.pb.cc
# AR -o .build_release/lib/libcaffe.a
# LD -o .build_release/lib/libcaffe.so.1.0.0
# CXX/LD -o .build_release/tools/test_net.bin
# CXX/LD -o .build_release/tools/train_net.bin
# CXX/LD -o .build_release/tools/upgrade_net_proto_binary.bin
# CXX/LD -o .build_release/tools/net_speed_benchmark.bin
# CXX/LD -o .build_release/tools/device_query.bin
# CXX/LD -o .build_release/tools/compute_image_mean.bin
# CXX/LD -o .build_release/tools/caffe.bin
# CXX/LD -o .build_release/tools/upgrade_solver_proto_text.bin
# CXX/LD -o .build_release/tools/finetune_net.bin
# CXX/LD -o .build_release/tools/convert_imageset.bin
# CXX/LD -o .build_release/tools/extract_features.bin
# CXX/LD -o .build_release/tools/upgrade_net_proto_text.bin
# CXX/LD -o .build_release/examples/mnist/convert_mnist_data.bin
# CXX/LD -o .build_release/examples/cpp_classification/classification.bin
# CXX/LD -o .build_release/examples/cifar10/convert_cifar_data.bin
# CXX/LD -o .build_release/examples/siamese/convert_mnist_siamese_data.bin

# %% [markdown]
# Now you should see `build` and `.build_release`. `.build_release` is hidden in the menu bar. However, you can call `!ls -a /content/caffe/` to see hidden files.

# %%
# !ls -a /content/caffe/
# Out:
# .		 CONTRIBUTORS.md  .github		   matlab
# ..		 data		  .gitignore		   models
# build		 distribute	  include		   python
# .build_release	 docker		  INSTALL.md		   README.md
# caffe.cloc	 docs		  LICENSE		   scripts
# cmake		 .Doxyfile	  Makefile		   src
# CMakeLists.txt	 examples	  Makefile.config	   tools
# CONTRIBUTING.md  .git		  Makefile.config.example  .travis.yml

# %%
# !ls -a /content/caffe/ | grep build
# Out:
# build
# .build_release

# %% [markdown]
# #### Compile DeepMatching GPU V1.0

# %% [markdown]
# You can download the source file [here](https://thoth.inrialpes.fr/src/deepmatching/code/deepmatching_gpu_1.0.zip).
# However, we modified a lot to accomodate to Caffe V1.0.
# So in this tutorial, we'll use our modified source file in `/content/STRAVE/opticFlow/web_gpudm_1.0_source`. Refer to `opticFlow/web_gpudm_1.0_source/README.txt` for more information.

# %%
# !cp /content/STRAVE/opticFlow/web_gpudm_1.0_source /content/web_gpudm_1.0

# %% [markdown]
# Then, add a softlink named `caffe` in the `web_gpudm_1.0` directory that points toward the `caffe` directory.

# %%
# !ln -s /content/caffe /content/web_gpudm_1.0/caffe

# %% [markdown]
# Next, install some packages we will need when compiling DeepMatching.
#
# You will need `swig` to automatically generate some scripts.
#
# If you use GPU backend, you will need `libgoogle-glog-dev`, or you will see the following error when running DeepMatching.
# ```
# GPU ImportError: libglog.so.0: cannot open shared object file: No such file or directory
# ```

# %%
# !sudo apt-get install swig
# !sudo apt-get install libgoogle-glog-dev  # When using GPU backend
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-140 linux-headers-4.15.0-140-generic r-cran-covr
#   r-cran-crosstalk r-cran-dt r-cran-htmlwidgets r-cran-later r-cran-lazyeval
#   r-cran-promises r-cran-rex
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   swig3.0
# Suggested packages:
#   swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   swig swig3.0
# 0 upgraded, 2 newly installed, 0 to remove and 4 not upgraded.
# Need to get 1,100 kB of archives.
# After this operation, 5,822 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Fetched 1,100 kB in 1s (1,160 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package swig3.0.
# (Reading database ... 203008 files and directories currently installed.)
# Preparing to unpack .../swig3.0_3.0.12-1_amd64.deb ...
# Unpacking swig3.0 (3.0.12-1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_3.0.12-1_amd64.deb ...
# Unpacking swig (3.0.12-1) ...
# Setting up swig3.0 (3.0.12-1) ...
# Setting up swig (3.0.12-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgoogle-glog-dev is already the newest version (0.3.5-1).
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-140 linux-headers-4.15.0-140-generic r-cran-covr
#   r-cran-crosstalk r-cran-dt r-cran-htmlwidgets r-cran-later r-cran-lazyeval
#   r-cran-promises r-cran-rex
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %% [markdown]
# You also need to let the system see libcaffe.so.1.0.0.
#
# You may see this message after running `!ldconfig`, but it doesn't matter.
# ```
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
# ```

# %%
# !echo /content/caffe/.build_release/lib > /etc/ld.so.conf.d/caffe.conf
# !ldconfig
# Out:
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %% [markdown]
# Now let's start compiling DeepMatching!
#
# Because DeepMatching only supports Python 2, and `python` may be called during compiling, we first let `python` point to Python 2.

# %%
# !mv /usr/local/bin/python /usr/local/bin/python3
# !ln -s /usr/bin/python2.7 /usr/local/bin/python
# !python --version
# Out:
# Python 2.7.17

# %% [markdown]
# We need to make twice.
#
# In the first time, you will see many warnings and errors. Don't panic! It will take 1 minute.
#
# It's expected that you see this error message. Now let's leave it behind and move on to the second make.
#
# ```
# Makefile:50: recipe for target 'gpudm_wrap.cxx' failed
# make: *** [gpudm_wrap.cxx] Error 202
# make: *** Waiting for unfinished jobs....
# ```

# %%
# %cd /content/web_gpudm_1.0/
# !make cleanswig
# !sudo make all -j2
# Out:
# /content/web_gpudm_1.0
# rm -f *.pyc *~ _gpudm.so gpudm_wrap.o ./extra_layers.o ./my_im2col.o ./extra_layers.cuo ./my_im2col.cuo
# rm -f gpudm.py gpudm_wrap.cxx gpudm_wrap.o
# swig -python -c++ -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include gpudm.swig
# g++ -g -O2 -c extra_layers.cpp -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -Lcaffe -o extra_layers.o
# caffe/include/caffe/common.hpp:31: Error: Unknown namespace 'google'
# caffe/include/caffe/common.hpp:120: Warning 362: operator= ignored
# caffe/include/caffe/common.hpp:125: Warning 325: Nested class not currently supported (RNG ignored)
# caffe/include/caffe/net.hpp:237: Warning 325: Nested class not currently supported (Callback ignored)
# caffe/include/caffe/layers/python_layer.hpp:9: Error: Unknown namespace 'boost::python'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:648: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:745: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:936: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1032: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1193: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1390: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1589: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2225: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2356: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2476: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2623: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2777: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3576: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3737: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3880: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3993: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4106: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4209: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4322: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4437: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4540: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4847: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4953: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5172: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5265: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5426: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5570: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5663: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5800: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5913: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6016: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6134: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6232: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6351: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6569: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6677: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6824: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6920: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7033: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7230: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7353: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7466: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7561: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7820: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7933: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8071: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8208: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8351: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8482: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8597: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8734: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8855: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8971: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9102: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9223: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9326: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9419: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9653: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9822: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10570: Warning 362: operator= ignored
# caffe/.build_release/src/caffe/proto/caffe.pb.h:11102: Warning 362: operator= ignored
# caffe/include/caffe/common.hpp:82: Warning 315: Nothing known about 'std::fstream'.
# caffe/include/caffe/common.hpp:83: Warning 315: Nothing known about 'std::ios'.
# caffe/include/caffe/common.hpp:84: Warning 315: Nothing known about 'std::isnan'.
# caffe/include/caffe/common.hpp:85: Warning 315: Nothing known about 'std::isinf'.
# caffe/include/caffe/common.hpp:86: Warning 315: Nothing known about 'std::iterator'.
# caffe/include/caffe/common.hpp:87: Warning 315: Nothing known about 'std::make_pair'.
# caffe/include/caffe/common.hpp:89: Warning 315: Nothing known about 'std::ostringstream'.
# caffe/include/caffe/common.hpp:93: Warning 315: Nothing known about 'std::stringstream'.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:726: Warning 503: Can't wrap 'caffe::protobuf_AddDesc_caffe_2eproto' unless renamed to a valid identifier.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:727: Warning 503: Can't wrap 'caffe::protobuf_AssignDesc_caffe_2eproto' unless renamed to a valid identifier.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:728: Warning 503: Can't wrap 'caffe::protobuf_ShutdownFile_caffe_2eproto' unless renamed to a valid identifier.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1258: Error: 'FillerParameter_VarianceNorm_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:107: Error: Previous declaration of 'FillerParameter_VarianceNorm_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1268: Error: 'FillerParameter_VarianceNorm_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:112: Error: Previous declaration of 'FillerParameter_VarianceNorm_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1271: Error: 'FillerParameter_VarianceNorm_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:116: Error: Previous declaration of 'FillerParameter_VarianceNorm_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1275: Error: 'FillerParameter_VarianceNorm_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:121: Error: Previous declaration of 'FillerParameter_VarianceNorm_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1652: Error: 'SolverParameter_SnapshotFormat_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:126: Error: Previous declaration of 'SolverParameter_SnapshotFormat_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1662: Error: 'SolverParameter_SnapshotFormat_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:131: Error: Previous declaration of 'SolverParameter_SnapshotFormat_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1665: Error: 'SolverParameter_SnapshotFormat_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:135: Error: Previous declaration of 'SolverParameter_SnapshotFormat_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1669: Error: 'SolverParameter_SnapshotFormat_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:140: Error: Previous declaration of 'SolverParameter_SnapshotFormat_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1678: Error: 'SolverParameter_SolverMode_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:145: Error: Previous declaration of 'SolverParameter_SolverMode_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1688: Error: 'SolverParameter_SolverMode_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:150: Error: Previous declaration of 'SolverParameter_SolverMode_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1691: Error: 'SolverParameter_SolverMode_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:154: Error: Previous declaration of 'SolverParameter_SolverMode_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1695: Error: 'SolverParameter_SolverMode_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:159: Error: Previous declaration of 'SolverParameter_SolverMode_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1712: Error: 'SolverParameter_SolverType_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:168: Error: Previous declaration of 'SolverParameter_SolverType_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1722: Error: 'SolverParameter_SolverType_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:173: Error: Previous declaration of 'SolverParameter_SolverType_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1725: Error: 'SolverParameter_SolverType_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:177: Error: Previous declaration of 'SolverParameter_SolverType_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:1729: Error: 'SolverParameter_SolverType_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:182: Error: Previous declaration of 'SolverParameter_SolverType_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2686: Error: 'ParamSpec_DimCheckMode_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:187: Error: Previous declaration of 'ParamSpec_DimCheckMode_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2696: Error: 'ParamSpec_DimCheckMode_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:192: Error: Previous declaration of 'ParamSpec_DimCheckMode_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2699: Error: 'ParamSpec_DimCheckMode_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:196: Error: Previous declaration of 'ParamSpec_DimCheckMode_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:2703: Error: 'ParamSpec_DimCheckMode_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:201: Error: Previous declaration of 'ParamSpec_DimCheckMode_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3804: Error: 'LossParameter_NormalizationMode_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:208: Error: Previous declaration of 'LossParameter_NormalizationMode_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3814: Error: 'LossParameter_NormalizationMode_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:213: Error: Previous declaration of 'LossParameter_NormalizationMode_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3817: Error: 'LossParameter_NormalizationMode_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:217: Error: Previous declaration of 'LossParameter_NormalizationMode_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:3821: Error: 'LossParameter_NormalizationMode_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:222: Error: Previous declaration of 'LossParameter_NormalizationMode_Parse'
# g++ -g -O2 -c my_im2col.cpp -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -Lcaffe -o my_im2col.o
# /usr/local/cuda-10.0/bin/nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_61,code=compute_61 -gencode arch=compute_75,code=[sm_75,compute_75] -Xcompiler -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -g -O2 -c extra_layers.cu -o extra_layers.cuo
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4605: Error: 'ConvolutionParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:228: Error: Previous declaration of 'ConvolutionParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4615: Error: 'ConvolutionParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:233: Error: Previous declaration of 'ConvolutionParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4618: Error: 'ConvolutionParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:237: Error: Previous declaration of 'ConvolutionParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:4622: Error: 'ConvolutionParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:242: Error: Previous declaration of 'ConvolutionParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5016: Error: 'DataParameter_DB_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:247: Error: Previous declaration of 'DataParameter_DB_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5026: Error: 'DataParameter_DB_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:252: Error: Previous declaration of 'DataParameter_DB_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5029: Error: 'DataParameter_DB_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:256: Error: Previous declaration of 'DataParameter_DB_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5033: Error: 'DataParameter_DB_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:261: Error: Previous declaration of 'DataParameter_DB_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5491: Error: 'EltwiseParameter_EltwiseOp_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:267: Error: Previous declaration of 'EltwiseParameter_EltwiseOp_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5495: Error: 'EltwiseParameter_EltwiseOp_MAX' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:266: Error: Previous declaration of 'EltwiseParameter_EltwiseOp_MAX'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5501: Error: 'EltwiseParameter_EltwiseOp_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:272: Error: Previous declaration of 'EltwiseParameter_EltwiseOp_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5504: Error: 'EltwiseParameter_EltwiseOp_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:276: Error: Previous declaration of 'EltwiseParameter_EltwiseOp_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:5508: Error: 'EltwiseParameter_EltwiseOp_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:281: Error: Previous declaration of 'EltwiseParameter_EltwiseOp_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6295: Error: 'HingeLossParameter_Norm_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:286: Error: Previous declaration of 'HingeLossParameter_Norm_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6305: Error: 'HingeLossParameter_Norm_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:291: Error: Previous declaration of 'HingeLossParameter_Norm_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6308: Error: 'HingeLossParameter_Norm_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:295: Error: Previous declaration of 'HingeLossParameter_Norm_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:6312: Error: 'HingeLossParameter_Norm_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:300: Error: Previous declaration of 'HingeLossParameter_Norm_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7096: Error: 'LRNParameter_NormRegion_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:305: Error: Previous declaration of 'LRNParameter_NormRegion_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7106: Error: 'LRNParameter_NormRegion_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:310: Error: Previous declaration of 'LRNParameter_NormRegion_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7109: Error: 'LRNParameter_NormRegion_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:314: Error: Previous declaration of 'LRNParameter_NormRegion_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7113: Error: 'LRNParameter_NormRegion_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:319: Error: Previous declaration of 'LRNParameter_NormRegion_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7124: Error: 'LRNParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:325: Error: Previous declaration of 'LRNParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7134: Error: 'LRNParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:330: Error: Previous declaration of 'LRNParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7137: Error: 'LRNParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:334: Error: Previous declaration of 'LRNParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7141: Error: 'LRNParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:339: Error: Previous declaration of 'LRNParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7626: Error: 'PoolingParameter_PoolMethod_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:345: Error: Previous declaration of 'PoolingParameter_PoolMethod_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7630: Error: 'PoolingParameter_PoolMethod_MAX' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:341: Error: Previous declaration of 'PoolingParameter_PoolMethod_MAX'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7636: Error: 'PoolingParameter_PoolMethod_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:350: Error: Previous declaration of 'PoolingParameter_PoolMethod_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7639: Error: 'PoolingParameter_PoolMethod_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:354: Error: Previous declaration of 'PoolingParameter_PoolMethod_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7643: Error: 'PoolingParameter_PoolMethod_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:359: Error: Previous declaration of 'PoolingParameter_PoolMethod_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7654: Error: 'PoolingParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:365: Error: Previous declaration of 'PoolingParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7664: Error: 'PoolingParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:370: Error: Previous declaration of 'PoolingParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7667: Error: 'PoolingParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:374: Error: Previous declaration of 'PoolingParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:7671: Error: 'PoolingParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:379: Error: Previous declaration of 'PoolingParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8275: Error: 'ReductionParameter_ReductionOp_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:386: Error: Previous declaration of 'ReductionParameter_ReductionOp_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8285: Error: 'ReductionParameter_ReductionOp_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:391: Error: Previous declaration of 'ReductionParameter_ReductionOp_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8288: Error: 'ReductionParameter_ReductionOp_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:395: Error: Previous declaration of 'ReductionParameter_ReductionOp_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8292: Error: 'ReductionParameter_ReductionOp_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:400: Error: Previous declaration of 'ReductionParameter_ReductionOp_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8416: Error: 'ReLUParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:406: Error: Previous declaration of 'ReLUParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8426: Error: 'ReLUParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:411: Error: Previous declaration of 'ReLUParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8429: Error: 'ReLUParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:415: Error: Previous declaration of 'ReLUParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8433: Error: 'ReLUParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:420: Error: Previous declaration of 'ReLUParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8799: Error: 'SigmoidParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:426: Error: Previous declaration of 'SigmoidParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8809: Error: 'SigmoidParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:431: Error: Previous declaration of 'SigmoidParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8812: Error: 'SigmoidParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:435: Error: Previous declaration of 'SigmoidParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:8816: Error: 'SigmoidParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:440: Error: Previous declaration of 'SigmoidParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9036: Error: 'SoftmaxParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:446: Error: Previous declaration of 'SoftmaxParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9046: Error: 'SoftmaxParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:451: Error: Previous declaration of 'SoftmaxParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9049: Error: 'SoftmaxParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:455: Error: Previous declaration of 'SoftmaxParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9053: Error: 'SoftmaxParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:460: Error: Previous declaration of 'SoftmaxParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9167: Error: 'TanHParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:466: Error: Previous declaration of 'TanHParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9177: Error: 'TanHParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:471: Error: Previous declaration of 'TanHParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9180: Error: 'TanHParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:475: Error: Previous declaration of 'TanHParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9184: Error: 'TanHParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:480: Error: Previous declaration of 'TanHParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9718: Error: 'SPPParameter_PoolMethod_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:486: Error: Previous declaration of 'SPPParameter_PoolMethod_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9722: Error: 'SPPParameter_PoolMethod_MAX' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:482: Error: Previous declaration of 'SPPParameter_PoolMethod_MAX'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9728: Error: 'SPPParameter_PoolMethod_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:491: Error: Previous declaration of 'SPPParameter_PoolMethod_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9731: Error: 'SPPParameter_PoolMethod_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:495: Error: Previous declaration of 'SPPParameter_PoolMethod_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9735: Error: 'SPPParameter_PoolMethod_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:500: Error: Previous declaration of 'SPPParameter_PoolMethod_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9746: Error: 'SPPParameter_Engine_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:506: Error: Previous declaration of 'SPPParameter_Engine_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9756: Error: 'SPPParameter_Engine_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:511: Error: Previous declaration of 'SPPParameter_Engine_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9759: Error: 'SPPParameter_Engine_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:515: Error: Previous declaration of 'SPPParameter_Engine_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9763: Error: 'SPPParameter_Engine_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:520: Error: Previous declaration of 'SPPParameter_Engine_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9961: Error: 'V1LayerParameter_LayerType_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:563: Error: Previous declaration of 'V1LayerParameter_LayerType_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9971: Error: 'V1LayerParameter_LayerType_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:568: Error: Previous declaration of 'V1LayerParameter_LayerType_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9974: Error: 'V1LayerParameter_LayerType_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:572: Error: Previous declaration of 'V1LayerParameter_LayerType_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9978: Error: 'V1LayerParameter_LayerType_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:577: Error: Previous declaration of 'V1LayerParameter_LayerType_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9987: Error: 'V1LayerParameter_DimCheckMode_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:582: Error: Previous declaration of 'V1LayerParameter_DimCheckMode_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:9997: Error: 'V1LayerParameter_DimCheckMode_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:587: Error: Previous declaration of 'V1LayerParameter_DimCheckMode_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10000: Error: 'V1LayerParameter_DimCheckMode_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:591: Error: Previous declaration of 'V1LayerParameter_DimCheckMode_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10004: Error: 'V1LayerParameter_DimCheckMode_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:596: Error: Previous declaration of 'V1LayerParameter_DimCheckMode_Parse'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10635: Error: 'V0LayerParameter_PoolMethod_IsValid' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:602: Error: Previous declaration of 'V0LayerParameter_PoolMethod_IsValid'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10639: Error: 'V0LayerParameter_PoolMethod_MAX' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:598: Error: Previous declaration of 'V0LayerParameter_PoolMethod_MAX'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10645: Error: 'V0LayerParameter_PoolMethod_descriptor' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:607: Error: Previous declaration of 'V0LayerParameter_PoolMethod_descriptor'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10648: Error: 'V0LayerParameter_PoolMethod_Name' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:611: Error: Previous declaration of 'V0LayerParameter_PoolMethod_Name'
# caffe/.build_release/src/caffe/proto/caffe.pb.h:10652: Error: 'V0LayerParameter_PoolMethod_Parse' is multiply defined in the generated target language module.
# caffe/.build_release/src/caffe/proto/caffe.pb.h:616: Error: Previous declaration of 'V0LayerParameter_PoolMethod_Parse'
# Makefile:50: recipe for target 'gpudm_wrap.cxx' failed
# make: *** [gpudm_wrap.cxx] Error 202
# make: *** Waiting for unfinished jobs....

# %% [markdown]
# It takes another 1 minute to finish the second make.

# %%
# %cd /content/web_gpudm_1.0/
# !sudo make -j2
# Out:
# /content/web_gpudm_1.0
# g++ -g -O2 -c gpudm_wrap.cxx -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -o gpudm_wrap.o
# /usr/local/cuda-10.0/bin/nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=sm_50 -gencode arch=compute_52,code=sm_52 -gencode arch=compute_60,code=sm_60 -gencode arch=compute_61,code=sm_61 -gencode arch=compute_61,code=compute_61 -gencode arch=compute_75,code=[sm_75,compute_75] -Xcompiler -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -g -O2 -c my_im2col.cu -o my_im2col.cuo
# g++ -g -O2 -fPIC -I/usr/include/python2.7 -Icaffe/include -I/usr/local/cuda-10.0/include -Igoogle_tools/include/ -I/usr/lib/x86_64-linux-gnu/atlas/include -Icaffe/include -Icaffe/.build_release/src -I/usr/include/hdf5/serial -I/usr/local/lib/python2.7/dist-packages/numpy/core/include -Lcaffe/build/lib gpudm_wrap.o extra_layers.o my_im2col.o extra_layers.cuo my_im2col.cuo -shared -o _gpudm.so -lcaffe -L/usr/local/cuda-10.0/lib64 -lcusparse
# CAFFEDIR=caffe; GOOGLETOOLS=google_tools; CUDA=/usr/local/cuda-10.0; MKL=/usr/lib/x86_64-linux-gnu/atlas; LD_LIBRARY_PATH="caffe/build/lib:/usr/local/cuda-10.0/lib64:/usr/lib/x86_64-linux-gnu/atlas/lib/intel64:/usr/lib64/openmpi/lib/:google_tools/lib:" python -c "import gpudm"

# %% [markdown]
# Don't forget to recover `python` to 3.x.

# %%
# !mv /usr/local/bin/python3 /usr/local/bin/python
# !python --version
# Out:
# Python 3.7.10

# %% [markdown]
# Now let's test if DeepMatching works.
#
# `gpudm.py` is automatically generated. There is a small error to fix. In line 14543, change `child_grid!=None` to `child_grid is not None`. Otherwise, you will see
# ```
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ```

# %%
with open('/content/web_gpudm_1.0/gpudm.py') as f:
  txt = f.read()
with open('/content/web_gpudm_1.0/gpudm.py', 'w') as f:
  f.write(txt.replace('child_grid!=None','child_grid is not None'))

# %% [markdown]
# Now let's run an example. Remenber to use `python2`.
#
# For GPU, simply add `-GPU` argument.
#
# See `/content/web_gpudm_1.0/README.txt` for more information.

# %% [markdown]
# You should get the following output:
# ```
# 36 36 36 26 3.77558 13
# 36 44 36 34 3.65536 24
# [...]
# 28 4 22 6 3.59854 94
# 28 20 28 10 3.75238 90
# 28 28 28 18 3.77126 83
# ```

# %%
# %cd /content/web_gpudm_1.0/
# CPU command
# !python2 deep_matching_gpu.py liberty1.png liberty2.png  
# GPU command
# !python2 deep_matching_gpu.py liberty1.png liberty2.png -GPU
# Out:
# /content/web_gpudm_1.0
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# E0412 19:52:28.814328 22372 common.cpp:114] Cannot create Cublas handle. Cublas won't be available.
# E0412 19:52:28.824152 22372 common.cpp:121] Cannot create Curand generator. Curand won't be available.
# found 49 correspondences for img pair 0
# 36 36 36 26 3.77558 0
# 36 44 36 34 3.65536 0
# 36 12 38 2 3.71165 0
# 36 52 42 52 3.69999 0
# 36 60 42 62 3.69605 0
# 36 20 36 10 3.77609 0
# 36 28 36 18 3.78784 0
# 44 36 44 30 3.78537 0
# 44 44 46 38 3.68796 0
# 44 12 44 0 3.71276 0
# 44 52 48 48 3.71118 0
# 44 60 50 58 3.67123 0
# 44 28 44 20 3.76802 0
# 12 36 10 42 3.72974 0
# 12 44 10 52 3.69926 0
# 12 12 8 18 3.68889 0
# 12 4 6 10 3.6482 0
# 12 20 8 26 3.66893 0
# 12 28 10 36 3.6736 0
# 52 36 52 26 3.78852 0
# 52 44 54 36 3.7071 0
# 52 12 52 0 3.73858 0
# 52 52 56 46 3.69766 0
# 52 60 58 54 3.64645 0
# 52 20 50 10 3.75464 0
# 52 28 52 16 3.76556 0
# 60 36 60 24 3.79248 0
# 60 44 62 34 3.62088 0
# 60 12 58 0 3.7401 0
# 60 20 58 8 3.76444 0
# 60 28 60 16 3.79014 0
# 4 36 2 44 3.74037 0
# 4 44 2 52 3.71631 0
# 4 12 0 20 3.6906 0
# 4 52 10 58 3.42024 0
# 4 20 0 30 3.71011 0
# 4 28 0 36 3.66269 0
# 20 36 18 40 3.65003 0
# 20 44 20 36 3.58783 0
# 20 52 24 56 3.63174 0
# 20 4 10 4 3.56637 0
# 20 28 18 30 3.6706 0
# 28 36 28 26 3.74204 0
# 28 44 26 36 3.67481 0
# 28 52 34 54 3.67438 0
# 28 60 28 52 3.64822 0
# 28 4 22 6 3.59854 0
# 28 20 28 10 3.75238 0
# 28 28 28 18 3.77126 0
